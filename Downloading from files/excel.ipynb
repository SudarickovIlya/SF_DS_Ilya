# %%
import pandas as pd

# %%
grades = pd.read_excel('data/grades.xlsx', index_col='Student ID', sheet_name='ML')
display(grades)

# Отвечаем на вопрос из модуля
print(f"Катя получила оценку {grades[grades['Student name'] == 'Катя']['Grade'].iloc[0]}")

grades = pd.read_excel('data/grades.xlsx', sheet_name='Maths', index_col='Student ID')
print(f"Оценка Миши за математику - {grades[grades['Student name'] == 'Миша']['Grade'].iloc[0]}")
# Out:
#            Student name  Grade
# Student ID
# 1                   Аня      7
# 2                  Катя      5
# 3                  Маша      9
# 4                  Миша      8
# 5                  Женя      9
# 6                   Оля      9
# 7                  Витя      7
# 8                  Дима      4
# 9                  Витя      5
# Катя получила оценку 5
# Оценка Миши за математику - 4

# %%
# Сохраняем данные из DataFrame grades в файл grades_new.xlsx (на листе 'Example') в папке data
grades.to_excel('data/new_grades.xlsx', sheet_name='Example', index=False)

# %%
data = pd.read_excel('https://github.com/asaydn/test/raw/master/january.xlsx')
display(data)
# Out:
#     January 2020 Sales Unnamed: 1 Unnamed: 2 Unnamed: 3   Unnamed: 4  \
# 0  Global Sales Report        NaN        NaN        NaN          NaN
# 1                  NaN        NaN        NaN        NaN          NaN
# 2             Location    Oranges     Apples    Bananas  Blueberries
# 3              Toronto       7651       4422       8580         3679
# 4          Los Angeles        273       2998       9890         7293
# 5              Atlanta       3758       6752       4599         4149
# 6             New York       4019       8796       8486         9188
#
#   Unnamed: 5
# 0        NaN
# 1        NaN
# 2      Total
# 3      24332
# 4      20454
# 5      19258
# 6      30489

# %%
ratings = pd.read_excel('data/ratings_movies.xlsx', sheet_name='ratings')
movies = pd.read_excel('data/ratings_movies.xlsx', sheet_name='movies')

# %%
ratings_movies = ratings.merge(movies, how='left', on='movieId')
display(ratings_movies)

# Ответ на контрольный вопрос
print(f"Количество строк в новой таблице - {ratings_movies.shape[0]}")
# Out:
#         userId  movieId  rating   timestamp                           title  \
# 0            1        1     4.0   964982703                Toy Story (1995)
# 1            1        3     4.0   964981247         Grumpier Old Men (1995)
# 2            1        6     4.0   964982224                     Heat (1995)
# 3            1       47     5.0   964983815     Seven (a.k.a. Se7en) (1995)
# 4            1       50     5.0   964982931      Usual Suspects, The (1995)
# ...        ...      ...     ...         ...                             ...
# 100831     610   166534     4.0  1493848402                    Split (2017)
# 100832     610   168248     5.0  1493850091   John Wick: Chapter Two (2017)
# 100833     610   168250     5.0  1494273047                  Get Out (2017)
# 100834     610   168252     5.0  1493846352                    Logan (2017)
# 100835     610   170875     3.0  1493846415  The Fate of the Furious (2017)
#
#                                              genres
# ...
